# %% [markdown]
# # Smallpond
#
# In this Notebook we will be focusing in testing the current environment and getting to know the tools that are involved

# %% [markdown]
# ## Imports

# %%
import ray
from minio import Minio
import os
import duckdb
import pandas as pd
import pyarrow.parquet as pq
from smallpond import init as smallpond_init

# %% [markdown]
# ## Testing pandas and duckdb
# In the following code you will create a simple pandas dataframe and then query it with duckdb and SQL

# %%
df = pd.DataFrame({"value": [10, 20, 30, 40, 50]})
result = duckdb.query("SELECT AVG(value) AS avg_value FROM df").to_df()
print(result)
# Out:
#    avg_value
# 0       30.0

# %% [markdown]
# ## Testing Ray
# You need to initialize Ray before running Smallpond. By sending the parameter address we are making sure to point to the correct Ray cluster.

# %%
print("initializing ray>>>>")
ray.init(address="ray://localhost:10001")  # Connects to ray-head which is running inside the cluster
print("Connected to Ray cluster:", ray.cluster_resources())
# Out:
# initializing ray>>>>
# Connected to Ray cluster: {'node:172.18.0.3': 1.0, 'CPU': 36.0, 'memory': 15675961346.0, 'object_store_memory': 7028316978.0, 'node:172.18.0.4': 1.0, 'node:__internal_head__': 1.0, 'node:172.18.0.5': 1.0}

# %%
@ray.remote
def f(x):
    return x * x

print("Running Ray tasks...")
results = ray.get([f.remote(i) for i in range(4)])
print("Results:", results)

print("Shutting down Ray")
ray.shutdown()
# Out:
# Running Ray tasks...
# Results: [0, 1, 4, 9]
# Shutting down Ray

# %% [markdown]
# If you don't initialize ray then Smallpond will initialize a single node local ray cluster but in that case we are missing the distribution power of Smallpond.

# %% [markdown]
# ## Testing MinIO

# %%
# Connect to MinIO
minio_client = Minio(
    endpoint=os.environ.get("MINIO_ENDPOINT", "http://localhost:9000").replace("http://", ""),
    access_key=os.environ.get("MINIO_ACCESS_KEY", "minioadmin"),
    secret_key=os.environ.get("MINIO_SECRET_KEY", "minioadmin"),
    secure=False,
)

# Create a bucket if it doesn’t exist
bucket_name = "my-data"
if not minio_client.bucket_exists(bucket_name):
    minio_client.make_bucket(bucket_name)
    print(f"Created bucket: {bucket_name}")
else:
    print(f"Bucket already exists: {bucket_name}")

object_name = "data/sample.parquet"
local_file_path = "notebooks/sample.parquet"  # "/Full/ path /to /your /file/data/sample.parquet"
# Upload the file
minio_client.fput_object(
            bucket_name,
            object_name,
            local_file_path,
)
print(f"File '{local_file_path}' uploaded as '{object_name}' to bucket '{bucket_name}'.")
# Out:
# Bucket already exists: my-data
# File 'sample.parquet' uploaded as 'data/sample.parquet' to bucket 'my-data'.

# %% [markdown]
# ### Let's go to the MinIO dashboard

# %% [markdown]
# ## Testing Smallpond
# In your virtual environment make sure to have the correct MinIO credentials running the following line:

# %%
os.environ["AWS_ACCESS_KEY_ID"] = "minioadmin"
os.environ["AWS_SECRET_ACCESS_KEY"] = "minioadmin"
os.environ["AWS_REGION"] = "us-east-1"
os.environ["AWS_ENDPOINT_URL"] = "http://localhost:9000"

# %% [markdown]
# This way we can pull data directly like we do from an S3 bucket with the notation: s3://

# %%
# Get's the data from the parquet file (in your bucket) using PyArrow
a_table = pq.read_table("s3://my-data/data/sample.parquet")

# %% [markdown]
# Initialize Ray and Smallpond

# %%
current_directory = os.getcwd()
print(f"The current working directory is: {current_directory}")

# Initialize Ray
ray.init(address="ray://localhost:10001")


# Smallpond is pointing the ray head at ray://localhost:10001
sp = smallpond_init(job_name="ProcessingTest", ray_address="ray://localhost:10001", data_root=os.path.join(current_directory, "data"), num_executors=2, bind_numa_node=False, executor_resources={"CPU": 4,"memory": 8,"object_store_memory": 2*1024})

df = sp.from_arrow(a_table)
print(df.take(10))
# Out:
# SIGTERM handler is not set because current thread is not the main thread.
# [2025-10-23 11:22:37.943836] [ZG-KPVW7DJYWV] [MainProcess(55435)] [task.py:414] INFO initialized logging to file: /Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/log/ZG-KPVW7DJYWV.log
# [2025-10-23 11:22:37.947280] [ZG-KPVW7DJYWV] [MainProcess(55435)] [task.py:426] INFO initialized user logging to file: /Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/log/ZG-KPVW7DJYWV-user.log
# [2025-10-23 11:22:37.947545] [ZG-KPVW7DJYWV] [MainProcess(55435)] [task.py:371] INFO set environment variable 'LD_LIBRARY_PATH': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib:'
# [2025-10-23 11:22:37.947626] [ZG-KPVW7DJYWV] [MainProcess(55435)] [task.py:373] INFO RANK='' LD_LIBRARY_PATH='/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib:' LD_PRELOAD='' MALLOC_CONF=''
# [2025-10-23 11:22:37.947699] [ZG-KPVW7DJYWV] [MainProcess(55435)] [task.py:333] INFO smallpond version: 0.15.0
# [2025-10-23 11:22:37.948018] [ZG-KPVW7DJYWV] [MainProcess(55435)] [task.py:334] INFO runtime context:
# {'bind_numa_node': False,
#  'completed_task_dir': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/staging/completed_tasks',
#  'config_root': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/config',
#  'console_log_level': 'INFO',
#  'current_task': None,
#  'data_root': 'data',
#  'disable_log_rotation': False,
#  'enable_diagnostic_metrics': False,
#  'enable_profiling': False,
#  'enforce_memory_limit': False,
#  'env_overrides': {},
#  'fault_inject_prob': 0.0,
#  'file_log_level': 'DEBUG',
#  'final_output_path': None,
#  'job_id': JobId('0ca14eab-fa9c-4a6c-8021-47c07d3fb58e'),
#  'job_root': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e',
#  'job_time': datetime.datetime(2025, 10, 23, 11, 22, 37, 923649),
#  'log_root': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/log',
#  'max_num_missed_probes': 6,
#  'max_usable_cpu_count': 1024,
#  'max_usable_gpu_count': 1024,
#  'max_usable_memory_size': 17592186044416,
#  'next_task_id': 0,
#  'num_executors': 2,
#  'numa_node_id': None,
#  'output_root': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/output',
#  'queue_root': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/queue',
#  'random_seed': ,
#  'remove_empty_parquet': False,
#  'secs_executor_probe_interval': 30,
#  'secs_wq_poll_interval': 0.5,
#  'shared_log_root': None,
#  'skip_task_with_empty_input': False,
#  'staging_root': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/staging',
#  'started_task_dir': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/staging/started_tasks',
#  'temp_root': '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/temp'}
# [2025-10-23 11:22:37.952919] [ZG-KPVW7DJYWV] [MainProcess(55435)] [task.py:335] INFO local GPUs: []
# [2025-10-23 11:22:37.953210] [ZG-KPVW7DJYWV] [MainProcess(55435)] [session.py:55] INFO using platform: Platform
# [2025-10-23 11:22:37.953281] [ZG-KPVW7DJYWV] [MainProcess(55435)] [session.py:56] INFO command-line arguments: /Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ipykernel_launcher.py -f /Users/valeryca/Library/Jupyter/runtime/kernel-739ac0bd-7aab-4cfd-b962-abc4e5682d4c.json
# [2025-10-23 11:22:37.953388] [ZG-KPVW7DJYWV] [MainProcess(55435)] [session.py:57] INFO session config: Config(job_id='0ca14eab-fa9c-4a6c-8021-47c07d3fb58e', job_time=datetime.datetime(2025, 10, 23, 11, 22, 37, 923649), data_root='data', num_executors=2, ray_address='ray://localhost:10001', bind_numa_node=False, memory_allocator='system', remove_output_root=True)
# [2025-10-23 11:22:37.953458] [ZG-KPVW7DJYWV] [MainProcess(55435)] [session.py:123] INFO connected to ray cluster at ray://localhost:10001
# [2025-10-23 11:22:37.995763] [ZG-KPVW7DJYWV] [MainProcess(55435)] [dataframe.py:234] INFO optimizing
# DataSourceNode-000001: input_deps=[], output_name=None, tasks[0]=[]...[], resource_limit=1CPUs/0GPUs/0GB, dataset=<ArrowTableDataSet: paths[0]=[]...', root_dir=/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop, columns=None>, file= /var/folders/lr/_bvhwjgn58bdmmyqz9l8hsyc0000gp/T/ipykernel_55435/385755028.py:7
# [2025-10-23 11:22:37.996039] [ZG-KPVW7DJYWV] [MainProcess(55435)] [dataframe.py:238] INFO optimized
# DataSourceNode-000001: input_deps=[], output_name=None, tasks[0]=[]...[], resource_limit=1CPUs/0GPUs/0GB, dataset=<ArrowTableDataSet: paths[0]=[]...', root_dir=/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop, columns=None>, file= /var/folders/lr/_bvhwjgn58bdmmyqz9l8hsyc0000gp/T/ipykernel_55435/385755028.py:7
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761240157.934144  793742 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1761240157.948477  793742 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1761240157.953967  793742 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1761240157.979757  793742 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# ---------------------------------------------------------------------------
# RayTaskError(FileNotFoundError)           Traceback (most recent call last)
# Cell In[4], line 8
#       5 sp = smallpond_init(job_name="ProcessingTest", ray_address="ray://localhost:10001", data_root="data", num_executors=2, bind_numa_node=False, executor_resources={"CPU": 4,"memory": 8,"object_store_memory": 2*1024})
#       7 df = sp.from_arrow(a_table)
# ----> 8 print(df.take(10))
#
# File ~/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/smallpond/dataframe.py:671, in DataFrame.take(self, limit)
#     665 """
#     666 Return up to `limit` rows.
#     667
#     668 This operation will trigger execution of the lazy transformations performed on this DataFrame.
#     669 """
#     670 if self.is_computed() or isinstance(self.plan, DataSourceNode):
# --> 671     datasets = self._compute()
#     672 else:
#     673     datasets = self.limit(limit)._compute()
#
# File ~/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/smallpond/dataframe.py:284, in DataFrame._compute(self)
#     282 for retry_count in range(3):
#     283     try:
# --> 284         return ray.get(
#     285             [task.run_on_ray() for task in self._get_or_create_tasks()]
#     286         )
#     287     except ray.exceptions.RuntimeEnvSetupError as e:
#     288         # XXX: Ray may raise this error when a worker is interrupted.
#     289         #      ```
#    (...)    295         #      However, since Ray dropped support for Python 3.8 since 2.11, we can not upgrade Ray.
#     296         #      So we catch this error and retry by ourselves.
#     297         logger.error(f"found ray RuntimeEnvSetupError, retrying...\n{e}")
#
# File ~/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:102, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#      98 if client_mode_should_convert():
#      99     # Legacy code
#     100     # we only convert init function if RAY_CLIENT_MODE=1
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
# --> 102         return getattr(ray, func.__name__)(*args, **kwargs)
#     103 return func(*args, **kwargs)
#
# File ~/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/util/client/api.py:42, in _ClientAPI.get(self, vals, timeout)
#      35 def get(self, vals, *, timeout=None):
#      36     """get is the hook stub passed on to replace `ray.get`
#      37
#      38     Args:
#      39         vals: [Client]ObjectRef or list of these refs to retrieve.
#      40         timeout: Optional timeout in milliseconds
#      41     """
# ---> 42     return self.worker.get(vals, timeout=timeout)
#
# File ~/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/util/client/worker.py:433, in Worker.get(self, vals, timeout)
#     431     op_timeout = max_blocking_operation_time
#     432 try:
# --> 433     res = self._get(to_get, op_timeout)
#     434     break
#     435 except GetTimeoutError:
#
# File ~/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/util/client/worker.py:461, in Worker._get(self, ref, timeout)
#     459         logger.exception("Failed to deserialize {}".format(chunk.error))
#     460         raise
# --> 461     raise err
#     462 if chunk.total_size > OBJECT_TRANSFER_WARNING_SIZE and log_once(
#     463     "client_object_transfer_size_warning"
#     464 ):
#     465     size_gb = chunk.total_size / 2**30
#
# RayTaskError(FileNotFoundError): ray::000001.DataSourceTask() (pid=454, ip=172.18.0.3)
#   File "/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/smallpond/execution/task.py", line 1152, in exec_task
#   File "/home/ray/anaconda3/lib/python3.11/pathlib.py", line 1108, in touch
#     fd = os.open(self, flags, mode)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/workshop/data/2025-10-23-11-22-37.0ca14eab-fa9c-4a6c-8021-47c07d3fb58e/staging/started_tasks/000001.DataSourceTask-000001.0'
# I0000 00:00:1761240217.990253  794893 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# 2025-10-23 11:23:38,001	WARNING api.py:293 -- Timeline will include events from other clients using this server.
# [2025-10-23 11:23:38.000568] [ZG-KPVW7DJYWV] [MainProcess(55435)] [session.py:264] WARNING graphviz is not installed, skipping graph dump
# [2025-10-23 11:23:39.019165] [ZG-KPVW7DJYWV] [MainProcess(55435)] [session.py:315] INFO progress: 1/1 tasks (100.0%)
# [2025-10-23 11:24:39.033918] [ZG-KPVW7DJYWV] [MainProcess(55435)] [session.py:264] WARNING graphviz is not installed, skipping graph dump
# Exception in thread dump_thread:
# Traceback (most recent call last):
#   File "/Users/valeryca/.pyenv/versions/3.11.11/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 788, in run_closure
#     _threading_Thread_run(self)
#   File "/Users/valeryca/.pyenv/versions/3.11.11/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/smallpond/session.py", line 310, in _dump_periodically
#     self.dump_timeline()
#   File "/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/smallpond/session.py", line 273, in dump_timeline
#     ray.timeline(exec_path)
#   File "/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/_private/state.py", line 962, in timeline
#     return state.chrome_tracing_dump(filename=filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/_private/state.py", line 455, in chrome_tracing_dump
#     self._check_connected()
#   File "/Users/valeryca/PycharmProjects/lightweight-analytics-duckdb-smallpond-oct2025/.venv/lib/python3.11/site-packages/ray/_private/state.py", line 53, in _check_connected
#     raise ray.exceptions.RaySystemError(
# ray.exceptions.RaySystemError: System error: Ray has not been started yet. You can start Ray with 'ray.init()'.

# %%
# Shuts down Ray
ray.shutdown()

# %% [markdown]
# ### Now let's check the Smallpond Dashboard
